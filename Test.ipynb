# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn']

# %%
plt.style.use('seaborn-colorblind')

# %%
np.random.seed(123)
df=pd.DataFrame({'A':np.random.randn(365).cumsum(0),
                'B':np.random.randn(365).cumsum(0)+20,
                'C':np.random.randn(365).cumsum(0)-20},
               index=pd.date_range('1/1/2017',periods=365))
df.head()
# Out:
#                    A          B          C
# 2017-01-01 -1.085631  20.059291 -20.230904
# 2017-01-02 -0.088285  21.803332 -16.659325
# 2017-01-03  0.194693  20.835588 -17.055481
# 2017-01-04 -1.311601  21.255156 -17.093802
# 2017-01-05 -1.890202  21.462083 -19.518638

# %%
dataSet = [[1, 1, 'yes'],
               [1, 1, 'yes'],
               [1, 0, 'no'],
               [0, 1, 'no'],
               [0, 1, 'no']]
dataSet[0]
# Out:
# [1, 1, 'yes']

# %%
df.plot('A','B',kind='scatter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
item={}
count_num=1

for i in range(10):
    name='name'+"count_num"
    item['name']=i*3
    count_num+=1
    print(item)
# Out:
# {'name': 0}
# {'name': 3}
# {'name': 6}
# {'name': 9}
# {'name': 12}
# {'name': 15}
# {'name': 18}
# {'name': 21}
# {'name': 24}
# {'name': 27}

# %%
data=pd.DataFrame(item,index=np.arange(10))

# %%
data
# Out:
#    name
# 0    27
# 1    27
# 2    27
# 3    27
# 4    27
# 5    27
# 6    27
# 7    27
# 8    27
# 9    27

# %%
astr='Hello bob'
try:
    istr=int(istr)
except:
    istr=-1
print(istr)
# Out:
# -1

# %%
astr='Bob'
try:
    print('Hello')
    astr=int(astr)
    print('There')
except:
    astr=-1
print('Done',istr)
# Out:
# Hello
# Done -1

# %%
data=pd.DataFrame({'A':[1,2,3,4],'B':['b','b','B','B']},index=np.arange(4))
data=pd.concat([data,data])
data.set_index(np.arange(8),inplace=True)

# %%
data
# Out:
#    A  B
# 0  1  b
# 1  2  b
# 2  3  B
# 3  4  B
# 4  1  b
# 5  2  b
# 6  3  B
# 7  4  B

# %%
data['A']=data['A'].map({1:'A',2:'B',3:'C',4:'D'})
data['B']=data.B.map({'b':1,'B':0})
data
# Out:
#    A  B
# 0  A  1
# 1  B  1
# 2  C  0
# 3  D  0
# 4  A  1
# 5  B  1
# 6  C  0
# 7  D  0

# %%
active=pd.read_excel('/Users/pein/Desktop/激活用户信息安卓1.5.xlsx')
register=pd.read_excel('/Users/pein/Desktop/注册用户信息.xlsx')
data=pd.merge(active,register,on='udid',how='left')
data.head()
# Out:
#                                udid            model    brand  平台   固件版本  \
# 0  159b4e4644a1e43173b713df06e1becc          m2 note    Meizu  安卓  安卓5.1
# 1  1bbd85f786a61dba1d6a2e560c9dd4b7              MX5    Meizu  安卓  安卓5.1
# 2  180ecbd39d4b5839c1cab21cd6c0fa91         SM-W2016  samsung  安卓  安卓5.1
# 3  037ee451bd2572a4a8bf8b96dc348e4a  Coolpad Y82-520   YuLong  安卓  安卓4.4
# 4  1172686fc584325abbb5b9932f3e9a2c         SM-J3109  samsung  安卓  安卓5.1
#
#        uid       p  gender  birthYear         phone            createOn  \
# 0      NaN     NaN     NaN        NaN           NaN                 NaT
# 1      NaN     NaN     NaN        NaN           NaN                 NaT
# 2  8056055  1002.0     1.0     1994.0  1.376692e+10 2017-04-19 23:51:16
# 3      NaN     NaN     NaN        NaN           NaN                 NaT
# 4  8055933  1002.0     1.0     1987.0  1.771598e+10 2017-04-19 23:34:33
#
#    sns_type
# 0       NaN
# 1       NaN
# 2       5.0
# 3       NaN
# 4       5.0

# %%
data.to_csv('/Users/pein/Desktop/result.csv')

# %%
data.model.value_counts().head(20)
# Out:
# OPPO                     31953
# vivo                     25927
# Xiaomi                   18002
# HUAWEI                   11055
# MHA-AL00                  2840
# EVA-AL10                  1869
# Le X620                   1753
# SM-G9350                  1402
# FRD-AL10                  1259
# Meizu                     1153
# VTR-AL00                  1096
# VIE-AL10                   909
# FRD-AL00                   822
# BLN-AL10                   819
# M5 Note                    771
# m3 note                    753
# Letv X500                  717
# LON-AL00                   716
# EVA-AL00                   696
# A31                        678
# MX5                        628
# m1 metal                   605
# VKY-AL00                   603
# R7Plusm                    562
# SM-G9280                   536
# m2 note                    532
# SM-G9250                   505
# PLK-AL10                   504
# Letv X501                  489
# H60-L01                    457
# ...

# %%
active_ios = pd.read_excel('/Users/pein/Desktop/激活信息IOS1.0.xlsx')
data1 = pd.merge(active_ios,register,on='udid',how='left')
data1.head()
# Out:
#                                udid   model      brand   平台     固件版本      uid  \
# 0  089623cab8a145cd9c4a31661dcc7041  iPhone  iPhone9,2  IOS  IOS10.3      NaN
# 1  14f0ea2b9ef84577973fa18e181cb510  iPhone  iPhone8,1  IOS   IOS9.1  8056054
# 2  19b2905c0f75446eb8b8612741c1f5d5  iPhone  iPhone9,1  IOS  IOS10.2  8056071
# 3  1dfca18b473647dd96aba5cc68d4e258  iPhone  iPhone7,1  IOS  IOS10.3  8056042
# 4  0e10dce8c59f4cdfa097c3a0b0553143  iPhone  iPhone8,1  IOS   IOS9.3  8055786
#
#         p  gender  birthYear         phone            createOn  sns_type
# 0     NaN     NaN        NaN           NaN                 NaT       NaN
# 1  1001.0     0.0     1987.0  1.354865e+10 2017-04-19 23:51:14       5.0
# 2  1001.0     0.0     1993.0  1.301648e+10 2017-04-19 23:54:01       5.0
# 3  1001.0     0.0     1993.0  1.884342e+10 2017-04-19 23:49:39       NaN
# 4  1001.0     0.0     1994.0  1.381260e+10 2017-04-19 23:20:18       5.0

# %%
data1.to_csv('/Users/pein/Desktop/dataIOS1.0.csv')

# %%
import xgboost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-afdaff4619ce> in <module>()
# ----> 1 import xgboost
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
import pandas as pd
juedui = pd.read_excel('/Users/pein/Desktop/绝对注册时间.xlsx')
xiangdui = pd.read_excel('/Users/pein/Desktop/相对注册时间.xlsx')

# %%
juedui_corr = juedui.corr()
xiangdui_corr = xiangdui.corr()

# %%
juedui_corr.to_csv('/Users/pein/Desktop/juedui.csv')
xiangdui_corr.to_csv('/Users/pein/Desktop/xiangdui.csv')

# %%
names = pd.Series([
    'Andre Agassi',
    'Barry Bonds',
    'Christopher Columbus',
    'Daniel Defoe',
    'Emilio Estevez',
    'Fred Flintstone',
    'Greta Garbo',
    'Humbert Humbert',
    'Ivan Ilych',
    'James Joyce',
    'Keira Knightley',
    'Lois Lane',
    'Mike Myers',
    'Nick Nolte',
    'Ozzy Osbourne',
    'Pablo Picasso',
    'Quirinus Quirrell',
    'Rachael Ray',
    'Susan Sarandon',
    'Tina Turner',
    'Ugueth Urbina',
    'Vince Vaughn',
    'Woodrow Wilson',
    'Yoji Yamada',
    'Zinedine Zidane'
])
split_name = names.split(" ")
print(split_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-97478e2e2a5b> in <module>()
#      26     'Zinedine Zidane'
#      27 ])
# ---> 28 split_name = names.split(" ")
#      29 print(split_name)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
import pandas as pd
